# %% [markdown]
# # UC Admissions Data Challenge Question Sprint
#
# This notebook-style submission mirrors `src/question_sprint_answers.py`. Run the script for the exact generated answer report.

# %%
# !python3 ../src/question_sprint_answers.py

# %% [markdown]
# ## Final Answers
#
# 1. Average campuses per applicant, Fall 2025: `5.74`
# 2. Fall 2025 UCLA admit rate: `0.0818`
# 3. Campus where Computer Science costs the most admit rate: `Davis`
# 4. Berkeley Computer Science admit GPA IQR: `0.09`
# 5. Campuses where White freshman admit rate is higher than Hispanic/Latino(a): `9`
# 6. Systemwide higher freshman admit-rate group: `Hispanic/Latino(a)`
# 7. Bay Area class of 2023 CCC enrollment share: `0.3364`
# 8. Mission San Jose 2023 UC applicants / a-g completers: `0.9906`
# 9. Distinct public high schools with at least one UC applicant in Fall 2025: `248`
# 10. Berkeley 2022-2025 largest positive residual among listed schools: `MISSION SENIOR HIGH SCHOOL`
